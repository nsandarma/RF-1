# %% [markdown]
# # ------ Import Library --------

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import string
import nltk
import re
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
df = pd.read_csv('hasil_crawling.csv')
df.head(5)
# Out:
#                         date         username  \
# 0  2022-10-24 14:37:10+00:00        ada_pohan
# 1  2022-10-24 14:33:36+00:00          PRDepok
# 2  2022-10-24 14:33:36+00:00   pikiran_rakyat
# 3  2022-10-24 14:28:44+00:00  antony_xenruang
# 4  2022-10-24 14:24:45+00:00     suaramerdeka
#
#                                                tweet
# 0  @SaropudinAde @Dennysiregar7 Lha yg maruk BLT ...
# 1  Cara Daftar BLT BBM 2022 Online Lewat HP di Ap...
# 2  Cara Daftar BLT BBM 2022 Online Lewat HP di Ap...
# 3  @NegeriKolam Kembali terbukti para kadrun itu ...
# 4  Siap-siap BLT BBM Bakal Cair Lagi di November ...

# %% [markdown]
# ## ------ Case Folding --------

# %%
df['tweet'] = df['tweet'].str.lower()
df['tweet'].head(5)
# Out:
# 0    @saropudinade @dennysiregar7 lha yg maruk blt ...
# 1    cara daftar blt bbm 2022 online lewat hp di ap...
# 2    cara daftar blt bbm 2022 online lewat hp di ap...
# 3    @negerikolam kembali terbukti para kadrun itu ...
# 4    siap-siap blt bbm bakal cair lagi di november ...
# Name: tweet, dtype: object

# %% [markdown]
# ## ----- Clean Text -------

# %%
# --------- Tokenizing --------------
def remove_tweet_special_char(text):
    # remove tab, new line, ans backspace
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")
df['tweet'] = df['tweet'].apply(remove_tweet_special_char)

#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

df['tweet'] = df['tweet'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

df['tweet'] = df['tweet'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df['tweet'] = df['tweet'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df['tweet'] = df['tweet'].apply(remove_whitespace_multiple)

# remove single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df['tweet'] = df['tweet'].apply(remove_singl_char)

# NLTK word rokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

df['tweet_tokens'] = df['tweet'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
df.head()
# Out:
# Tokenizing Result :
#                         date         username  \
# 0  2022-10-24 14:37:10+00:00        ada_pohan
# 1  2022-10-24 14:33:36+00:00          PRDepok
# 2  2022-10-24 14:33:36+00:00   pikiran_rakyat
# 3  2022-10-24 14:28:44+00:00  antony_xenruang
# 4  2022-10-24 14:24:45+00:00     suaramerdeka
#
#                                                tweet  \
# 0                  lha yg maruk blt kelian orang koq
# 1  cara daftar blt bbm online lewat hp di aplikas...
# 2  cara daftar blt bbm online lewat hp di aplikas...
# 3  kembali terbukti para kadrun itu punya tabiat ...
# 4  siapsiap blt bbm bakal cair lagi di november l...
#
#                                         tweet_tokens
# 0          [lha, yg, maruk, blt, kelian, orang, koq]
# 1  [cara, daftar, blt, bbm, online, lewat, hp, di...
# 2  [cara, daftar, blt, bbm, online, lewat, hp, di...
# 3  [kembali, terbukti, para, kadrun, itu, punya, ...
# 4  [siapsiap, blt, bbm, bakal, cair, lagi, di, no...

# %% [markdown]
# ## ------ Kalkulasi Frekuensi Distribusi ---------

# %%
# NLTK calc frequency distribution
def freqDist_wrapper(text):
    return FreqDist(text)

df['tweet_tokens_fdist'] = df['tweet_tokens'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
print(df['tweet_tokens_fdist'].head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(lha, 1), (yg, 1), (maruk, 1), (blt, 1), (kel...
# 1    [(cara, 1), (daftar, 1), (blt, 1), (bbm, 1), (...
# 2    [(cara, 1), (daftar, 1), (blt, 1), (bbm, 1), (...
# 3    [(kembali, 1), (terbukti, 1), (para, 1), (kadr...
# 4    [(di, 2), (siapsiap, 1), (blt, 1), (bbm, 1), (...
# Name: tweet_tokens_fdist, dtype: object

# %% [markdown]
# ## ------- StopWords ---------

# %%
from nltk.corpus import stopwords

# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')


# ---------------------------- manualy add stopword  ------------------------------------
# append additional stopword
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah','koq'])


#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

df['tweet_tokens_WSW'] = df['tweet_tokens'].apply(stopwords_removal) 


print(df['tweet_tokens_WSW'].sample(5))
# Out:
# 133             [blt, bbm, jaga, daya, beli, masyarakat]
# 642    [takalarbabinsa, koramil, marbo, desa, tope, j...
# 709       [pembagian, blt, mudah, sasaran, dki, jakarta]
# 163          [diperhatikan, penerimaan, blt, bbm, jambi]
# 239    [lampung, apresiasi, kebijakan, pemerintah, bl...
# Name: tweet_tokens_WSW, dtype: object

# %% [markdown]
# ## --------- Stemming ----------

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['tweet_tokens_WSW']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    # print(term,":" ,term_dict[term])

print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df['tweet_tokens_stemmed'] = df['tweet_tokens_WSW'].swifter.apply(get_stemmed_term)
# Out:
# 740
# ------------------------
# ------------------------
# Pandas Apply:   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
df.tweet_tokens_stemmed.to_csv('data_stemmed.csv',index=True)

# %% [markdown]
# ## ------- Final Tweet ----------

# %%
def final_tweet(text):
    text =  ' '.join(text)
    return text
df['final_tweet'] = df['tweet_tokens_stemmed'].apply(final_tweet)
df
# Out:
#                           date         username  \
# 0    2022-10-24 14:37:10+00:00        ada_pohan
# 1    2022-10-24 14:33:36+00:00          PRDepok
# 2    2022-10-24 14:33:36+00:00   pikiran_rakyat
# 3    2022-10-24 14:28:44+00:00  antony_xenruang
# 4    2022-10-24 14:24:45+00:00     suaramerdeka
# ..                         ...              ...
# 995  2022-10-24 07:13:11+00:00  randy_saputra78
# 996  2022-10-24 07:12:50+00:00  randy_saputra78
# 997  2022-10-24 07:12:47+00:00     clartDonn034
# 998  2022-10-24 07:12:40+00:00  Gunawan76595624
# 999  2022-10-24 07:12:29+00:00  randy_saputra78
#
#                                                  tweet  \
# 0                    lha yg maruk blt kelian orang koq
# 1    cara daftar blt bbm online lewat hp di aplikas...
# 2    cara daftar blt bbm online lewat hp di aplikas...
# 3    kembali terbukti para kadrun itu punya tabiat ...
# 4    siapsiap blt bbm bakal cair lagi di november l...
# ..                                                 ...
# 995  pemerintah berupaya sejahterakan rakyat dengan...
# 996  blt bbm sejahterakan rakyat terima kasih presi...
# 997  papua barat bijak manfaatkan blt bbm blt bbm u...
# 998                                  blt tepat sasaran
# 999       penyaluran blt bbm untuk membantu masyarakat
#
#                                           tweet_tokens  \
# 0            [lha, yg, maruk, blt, kelian, orang, koq]
# 1    [cara, daftar, blt, bbm, online, lewat, hp, di...
# 2    [cara, daftar, blt, bbm, online, lewat, hp, di...
# 3    [kembali, terbukti, para, kadrun, itu, punya, ...
# 4    [siapsiap, blt, bbm, bakal, cair, lagi, di, no...
# ..                                                 ...
# 995  [pemerintah, berupaya, sejahterakan, rakyat, d...
# 996  [blt, bbm, sejahterakan, rakyat, terima, kasih...
# 997  [papua, barat, bijak, manfaatkan, blt, bbm, bl...
# 998                              [blt, tepat, sasaran]
# 999  [penyaluran, blt, bbm, untuk, membantu, masyar...
#
#                                     tweet_tokens_fdist  \
# 0    {'lha': 1, 'yg': 1, 'maruk': 1, 'blt': 1, 'kel...
# 1    {'cara': 1, 'daftar': 1, 'blt': 1, 'bbm': 1, '...
# 2    {'cara': 1, 'daftar': 1, 'blt': 1, 'bbm': 1, '...
# 3    {'kembali': 1, 'terbukti': 1, 'para': 1, 'kadr...
# 4    {'siapsiap': 1, 'blt': 1, 'bbm': 1, 'bakal': 1...
# ..                                                 ...
# 995  {'pemerintah': 1, 'berupaya': 1, 'sejahterakan...
# 996  {'blt': 1, 'bbm': 1, 'sejahterakan': 1, 'rakya...
# 997  {'papua': 1, 'barat': 1, 'bijak': 1, 'manfaatk...
# 998               {'blt': 1, 'tepat': 1, 'sasaran': 1}
# 999  {'penyaluran': 1, 'blt': 1, 'bbm': 1, 'untuk':...
#
#                                       tweet_tokens_WSW  \
# 0                     [lha, maruk, blt, kelian, orang]
# 1    [daftar, blt, bbm, online, hp, aplikasi, cek, ...
# 2    [daftar, blt, bbm, online, hp, aplikasi, cek, ...
# 3    [terbukti, kadrun, tabiat, karakter, pecundang...
# 4    [siapsiap, blt, bbm, cair, november, lihat, na...
# ..                                                 ...
# 995  [pemerintah, berupaya, sejahterakan, rakyat, b...
# 996  [blt, bbm, sejahterakan, rakyat, terima, kasih...
# 997  [papua, barat, bijak, manfaatkan, blt, bbm, bl...
# 998                                     [blt, sasaran]
# 999       [penyaluran, blt, bbm, membantu, masyarakat]
#
#                                   tweet_tokens_stemmed  \
# 0                     [lha, maruk, blt, kelian, orang]
# 1    [daftar, blt, bbm, online, hp, aplikasi, cek, ...
# 2    [daftar, blt, bbm, online, hp, aplikasi, cek, ...
# 3    [bukti, kadrun, tabiat, karakter, cundang, sen...
# 4    [siapsiap, blt, bbm, cair, november, lihat, na...
# ..                                                 ...
# 995     [perintah, upaya, sejahtera, rakyat, blt, bbm]
# 996  [blt, bbm, sejahtera, rakyat, terima, kasih, p...
# 997  [papua, barat, bijak, manfaat, blt, bbm, blt, ...
# 998                                       [blt, sasar]
# 999               [salur, blt, bbm, bantu, masyarakat]
#
#                                            final_tweet
# 0                           lha maruk blt kelian orang
# 1    daftar blt bbm online hp aplikasi cek bansos c...
# 2    daftar blt bbm online hp aplikasi cek bansos c...
# 3    bukti kadrun tabiat karakter cundang senang re...
# 4    siapsiap blt bbm cair november lihat nama teri...
# ..                                                 ...
# 995            perintah upaya sejahtera rakyat blt bbm
# 996  blt bbm sejahtera rakyat terima kasih presiden...
# 997  papua barat bijak manfaat blt bbm blt bbm blt ...
# 998                                          blt sasar
# 999                     salur blt bbm bantu masyarakat
#
# [1000 rows x 8 columns]

# %%
# final to Labelling
# df.final_tweet.to_csv('to_labelling3.csv',index=False)

# %%
df = pd.read_csv('hasil_labelling3.csv')

# %% [markdown]
# setelah cleaning maka perlu dilakukan labelling sentiment menggunakan aplikasi orange ....

# %%
df
# Out:
#      sentiment                                        final_tweet
# 0     0.000000                         lha maruk blt kelian orang
# 1     0.000000  daftar blt bbm online hp aplikasi cek bansos c...
# 2     0.000000  daftar blt bbm online hp aplikasi cek bansos c...
# 3    14.285714  bukti kadrun tabiat karakter cundang senang re...
# 4    11.111111  siapsiap blt bbm cair november lihat nama teri...
# ..         ...                                                ...
# 994   0.000000            perintah upaya sejahtera rakyat blt bbm
# 995  25.000000  blt bbm sejahtera rakyat terima kasih presiden...
# 996  16.666667  papua barat bijak manfaat blt bbm blt bbm blt ...
# 997   0.000000                                          blt sasar
# 998   0.000000                     salur blt bbm bantu masyarakat
#
# [999 rows x 2 columns]

# %%
def conv(sentiment):
    if sentiment >= 1 :
        return 1
    elif sentiment == 0:
        return 0
    else:
        return -1
df['sentiment_norm'] = df['sentiment'].apply(conv)

# %%
df[df['sentiment_norm'] == -1 ]
# Out:
#      sentiment                                        final_tweet  \
# 27  -20.000000                        blt bbm cegah ancam inflasi
# 28  -20.000000                        blt bbm cegah ancam inflasi
# 29  -20.000000                        blt bbm cegah ancam inflasi
# 30  -20.000000                        blt bbm cegah ancam inflasi
# 35  -33.333333                                      blt bom turun
# 37  -14.285714  bohong menteri profesional ngutang blt copras ...
# 45  -16.666667                 id dumdum negara wajib layan layan
# 93   -7.142857  tangan dampak inflasi pemkot surabaya gelontor...
# 120 -18.750000  kurang dampak inflasi pemkot kota surabaya ser...
# 127 -11.111111  pemkot surabaya bagi blt bbm kemudi angkut tek...
# 130 -22.222222  presiden joko widodo tingkat inflasi ri golong...
# 183  -9.090909  heuhwuhwuhwu silah ambil blt mu dpn kantor pos...
# 195  -8.333333  tanjung menteri status nkri eh tangkap kpk amb...
# 217 -22.222222  blt bukti tahan inflasi jaga daya beli kelompo...
# 241 -10.000000  eri cahyadi atas dampak inflasi gelontor rp bl...
# 262  -8.333333  perintah usaha kendali inflasi akibat sesuai h...
# 265 -18.181818  pasca sesuai harga bbm perintah milik strategi...
# 308 -20.000000                     blt cair sasar rakyat khawatir
# 404 -20.000000                          putus jokowi bagi blt bbm
# 414 -20.000000                          putus jokowi bagi blt bbm
# 453 -14.285714  blt bbm bsu masyarakat meringakan beban masyar...
# 468 -20.000000                    masyarakat rentan bantu blt bbm
# 483 -20.000000                    masyarakat rentan bantu blt bbm
# 503 -20.000000                    masyarakat rentan bantu blt bbm
# 522 -20.000000                    masyarakat rentan bantu blt bbm
# 523 -14.285714  blt bbm bsu masyarakat meringakan beban masyar...
# 524 -14.285714  blt bbm bsu masyarakat meringakan beban masyar...
# 525 -14.285714  blt bbm bsu masyarakat meringakan beban masyar...
# 526 -14.285714  blt bbm bsu masyarakat meringakan beban masyar...
# 527 -14.285714  blt bbm bsu masyarakat meringakan beban masyar...
# 528 -14.285714  blt bbm bsu masyarakat meringakan beban masyar...
# 730 -20.000000                          putus jokowi bagi blt bbm
# 734 -20.000000                          putus jokowi bagi blt bbm
# 741 -20.000000                          putus jokowi bagi blt bbm
# 756  -9.090909  ojol bkn dar ojol jln daerah menganalisa peeta...
# 780 -20.000000                          putus jokowi bagi blt bbm
# 827 -11.111111  blt bbm bsu bantu masyarakat kalimantan utara ...
# 875 -12.500000   blt bbm dongkrak daya beli masyarakat malu utara
# 902 -10.000000  apresiasi inflasi akibat sesuai harga bbm rend...
#
#      sentiment_norm
# 27               -1
# 28               -1
# 29               -1
# 30               -1
# 35               -1
# 37               -1
# 45               -1
# 93               -1
# 120              -1
# 127              -1
# 130              -1
# 183              -1
# 195              -1
# 217              -1
# 241              -1
# 262              -1
# 265              -1
# 308              -1
# 404              -1
# 414              -1
# 453              -1
# 468              -1
# 483              -1
# 503              -1
# 522              -1
# 523              -1
# 524              -1
# 525              -1
# 526              -1
# 527              -1
# 528              -1
# 730              -1
# 734              -1
# 741              -1
# 756              -1
# 780              -1
# 827              -1
# 875              -1
# 902              -1

# %%
df.to_csv('hasil_labelling.csv',index=False)
